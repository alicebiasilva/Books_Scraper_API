# %%
import pandas as pd

# %%
df = pd.read_csv("D:/FIAP/Engenharia de Machine Learning/Fase 1/Projeto1/api/data/books.csv")

# %%
df.head(5)
# Out:
#                                                title  price availability  \
# 0                            It's Only the Himalayas  45.17     In stock
# 1  Full Moon over Noahâs Ark: An Odyssey to Mou...  49.43     In stock
# 2  See America: A Celebration of Our National Par...  48.87     In stock
# 3  Vagabonding: An Uncommon Guide to the Art of L...  36.94     In stock
# 4                               Under the Tuscan Sun  37.33     In stock
#
#   rating category                                         image_path  id
# 0    Two   Travel  https://github.com/alicebiasilva/Pos_Tech_Mach...   1
# 1   Four   Travel  https://github.com/alicebiasilva/Pos_Tech_Mach...   2
# 2  Three   Travel  https://github.com/alicebiasilva/Pos_Tech_Mach...   3
# 3    Two   Travel  https://github.com/alicebiasilva/Pos_Tech_Mach...   4
# 4  Three   Travel  https://github.com/alicebiasilva/Pos_Tech_Mach...   5

# %%
df['image_path'][1]
# Out:
# 'https://github.com/alicebiasilva/Pos_Tech_Machine_Learning_Engineer/blob/main/public/images/57770cac1628f4407636635f4b85e88c.jpg'

# %%
| Fase        | Ação                                                                | Prioridade |
| ----------- | ------------------------------------------------------------------- | ---------- |
| Curto prazo | Mudar CSV para banco de dados simples + paralelizar scraping básico | Alta       |
| Médio prazo | API escalável com balanceamento, cache e deploy em cloud            | Alta       |
| Médio prazo | Usar CDN e armazenamento cloud para imagens                         | Média      |
| Longo prazo | Arquitetura microserviços, monitoramento, segurança avançada        | Alta       |
